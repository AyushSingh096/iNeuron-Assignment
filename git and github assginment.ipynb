# %% [markdown]
# ## ASSIGNMENT - 1 GIT and GITHUB

# %% [markdown]
# #Task - 1

# %% [markdown]
# Demonstrate minimum 15 basic docker command with explanation and screenshot.

# %% [markdown]
# 1. git status : it will tell us the state of repository and chnges in code
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 2. git add .  :
# Stage all files and directories in the working tree unless specified otherwise
# It will add all the recent changes done in code and in repositry
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. git restore --staged . :
# It will restore all the changes from staged to unstaged.
# unstaged the changes from commit
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. git commit -m "msg" :
# commit to recent changes so that it can come to staging layer and "msg" is massege for commit
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. git push -u origin main :
# Thish command push the code available in staging to main in git reposetory
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. git branch -M main :
# It will change the git barnch to main
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. git init :
# This is the first command used in project to create new git repository (initilize the git reposetory for that project)

# %% [markdown]
# 8. git remote add origin <github_url>    :-
# This command is used to connect the local project with the github reposetory created on github using the url provided in <github_url>. It will stagged all the local project file to github after the push command the files will be available in github.

# %% [markdown]
# 9. git clone <url>    :
# this command is used to clone any github repository into your local system as project.
# ![image.png](attachment:image.png)

# %% [markdown]
# 10. git config
# a)git config –global user.name “[name]”
#
# b)git config –global user.email “[email address]”
#
# This command sets the author name and email address respectively to be used with your commits.
# ![image.png](attachment:image.png)

# %% [markdown]
# 11. git branch developer1   : It will create new branch in repository named as developer1
# ![image.png](attachment:image.png)

# %% [markdown]
# 12. git checkout developer1 : using this we will switch to developer1 branch now change will be done only in developer1 branch
# ![image.png](attachment:image.png)

# %% [markdown]
# 13. git merge developer1 : It will merge all the changes done in developer branch into main branch
# ![image.png](attachment:image.png)

# %% [markdown]
# 14. git log  : it will give us the log details of all the commit happens till now in git reposetory.
# ![image.png](attachment:image.png)

# %% [markdown]
# 15. git branch -d developer1 : this is used to delete the git branch "It will delete the developer1 branch"
# ![image.png](attachment:image.png)
